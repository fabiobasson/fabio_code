# %% [markdown]
# Provedores de LLMs (OpenAIo, Cohere, Hugging Face, etc) - a classe LLM e projetada para fornecer uma interface padrão a todos eles.

# %%
#pip install -r requirements.txt
! pip install -r requirements.txt
# Criar a API KEY na OPENAI
#https://platform.openai.com/settings/organization/api-keys

# %%
#Google Generative AI (Gemini API & AI Studio)

from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages import HumanMessage

from dotenv import load_dotenv

load_dotenv() # ler todas as chaves da variavel .env

llm = ChatGoogleGenerativeAI(model="gemini-pro")

# Simple text invocation
result = llm.invoke("Sing a ballad of LangChain.")
print(result.content)

# %%
import getpass
import os

try:
    # load environment variables from .env file (requires `python-dotenv`)
    from dotenv import load_dotenv

    load_dotenv()
except ImportError:
    pass

os.environ["LANGSMITH_TRACING"] = "true"
if "LANGSMITH_API_KEY" not in os.environ:
    os.environ["LANGSMITH_API_KEY"] = getpass.getpass(
        prompt="Enter your LangSmith API key (optional): "
    )
if "LANGSMITH_PROJECT" not in os.environ:
    os.environ["LANGSMITH_PROJECT"] = getpass.getpass(
        prompt='Enter your LangSmith Project Name (default = "default"): '
    )
    if not os.environ.get("LANGSMITH_PROJECT"):
        os.environ["LANGSMITH_PROJECT"] = "default"
if "OPENAI_API_KEY" not in os.environ:
    os.environ["OPENAI_API_KEY"] = getpass.getpass(
        prompt="Enter your OpenAI API key (required if using OpenAI): "
    )

# %% [markdown]
# Chamando a LLM

# %%
from langchain_openai import OpenAI
from dotenv import load_dotenv

llm = OpenAI()

pergunta = "fala sobre clubes de futebol"
llm.invoke(pergunta)

for trecho in llm.stream(pergunta):
    print(trecho, end ='')
# Out:
# Os clubes de futebol são organizações esportivas que possuem times profissionais e amadores de futebol. São responsáveis por manter e administrar as equipes, além de gerir aspectos financeiros, estruturais e técnicos relacionados ao esporte.
#
# No Brasil, os clubes de futebol são muito populares e possuem uma grande importância social e cultural. São vistos como uma parte fundamental da identidade das cidades e regiões onde estão sediados, representando não apenas um time, mas também uma comunidade e suas tradições.
#
# Os clubes de futebol geralmente são constituídos por sócios, que pagam uma mensalidade para terem acesso a benefícios e participarem das decisões do clube. Além disso, eles também contam com patrocinadores e receitas provenientes de venda de ingressos, produtos licenciados e direitos de transmissão de jogos.
#
# Dentre os principais objetivos dos clubes de futebol estão a formação de atletas, a conquista de títulos e a participação em campeonatos nacionais

# %%
perguntas = ['conte a estoria da Vasco',
              'fale sobre sql']
llm.batch(perguntas)

# %%
# Simple text invocation
result = llm.invoke("Sing a ballad of LangChain.")
print(result,  end ='')

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI()
llm.invoke("Hello, world!")

# %%
if not os.environ.get("OPENAI_API_KEY"):
  os.environ["OPENAI_API_KEY"] = getpass.getpass("Enter API key for OpenAI: ")

from langchain.chat_models import init_chat_model

model = init_chat_model("gpt-4o-mini", model_provider="openai")

# %% [markdown]
# Let's first use the model directly. ChatModels are instances of LangChain Runnables, which means they expose a standard interface for interacting with them. To simply call the model, we can pass in a list of messages to the .invoke method.

# %%
from langchain_core.messages import HumanMessage, SystemMessage

messages = [
    SystemMessage("Translate the following from English into Italian"),
    HumanMessage("hi!"),
]

model.invoke(messages)
